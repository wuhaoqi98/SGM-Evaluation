# %%
# Reload modules whenever underlying code changes
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
from sgm.dependencies import *

# %% [markdown]
# # Initialize untrained agent

# %%
tf.reset_default_graph()

# %%
from sgm.envs import env_load_fn
from sgm.agent import UvfAgent

# If you change the environment parameters below, make sure to run
# tf.reset_default_graph() in the cell above before training.
max_episode_steps = 20
env_name = 'FourRooms'  # Choose one of the environments shown above. 
resize_factor = 5  # Inflate the environment to increase the difficulty.
thin = True # If True, resize by expanding open space, not walls, to make walls thin
desc_name = "thinned_" + env_name.lower() if thin else env_name.lower()

base_dir = os.path.join(os.getcwd(), os.pardir, "agents")
model_dir = os.path.join(base_dir, desc_name)

tf_env = env_load_fn(env_name, max_episode_steps,
                     resize_factor=resize_factor,
                     terminate_on_timeout=False,
                     thin=thin)

eval_tf_env = env_load_fn(env_name, max_episode_steps,
                          resize_factor=resize_factor,
                          terminate_on_timeout=True,
                          thin=thin)

agent = UvfAgent(
    tf_env.time_step_spec(),
    tf_env.action_spec(),
    max_episode_steps=max_episode_steps,
    use_distributional_rl=True,
    ensemble_size=3)
# Out:
# d:\anaconda3\envs\sgm\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# WARNING:tensorflow:From d:\anaconda3\envs\sgm\lib\site-packages\tf_agents\agents\ddpg\actor_network.py:101: The name tf.keras.initializers.RandomUniform is deprecated. Please use tf.compat.v1.keras.initializers.RandomUniform instead.

# %% [markdown]
# # Train the agent

# %%
from sgm.trainer import train_eval

train_eval(agent,
           tf_env,
           eval_tf_env,
           initial_collect_steps=1000,
           eval_interval=1000,
           num_eval_episodes=10,
           num_iterations=3000,
           save_model_dir=model_dir,
           experiment_name=f"{env_name}_coordinate_{max_episode_steps}steps")
# Out:
# INFO:tensorflow:random_seed = 0
# Executing op Range in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarIsInitializedOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AssignVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MutexV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Fill in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LogicalNot in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Assert in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Reshape in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_initialize_variables_19542252 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_run_19542537 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op TensorDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op RepeatDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ScanDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ParallelMapDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op PrefetchDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op OptimizeDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ModelDataset in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AnonymousIteratorV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MakeIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:Saving checkpoints to directory D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-13-2021-10-58-11-PM\ckpt
# INFO:tensorflow:Creating tensorboard summary writer with directory D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-13-2021-10-58-11-PM
# Executing op SummaryWriter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op CreateSummaryFileWriter in device /job:localhost/replica:0/task:0/device:CPU:0
#   0%|                                                                                         | 0/3000 [00:00<?, ?it/s]
# Executing op AssignAddVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_run_19543016 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op IteratorGetNextSync in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op VarHandleOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_initialize_variables_19544974 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_train_19546455 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op LogicalAnd in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op WriteScalarSummary in device /job:localhost/replica:0/task:0/device:CPU:0
#   0%|                                                                               | 1/3000 [00:01<1:34:41,  1.89s/it]
# Executing op __inference_run_19546753 in device /job:localhost/replica:0/task:0/device:CPU:0
#  33%|█████████████████████████▍                                                    | 979/3000 [00:06<00:09, 209.97it/s]
# Executing op AssignAddVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StringJoin in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ShardedFilename in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ReadVariableOp in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op SaveV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Pack in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MergeV2Checkpoints in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Saved checkpoint for step 1000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-13-2021-10-58-11-PM\ckpt\ckpt-1
# INFO:tensorflow:step = 1000, loss = 2.279223
# INFO:tensorflow:155.226 steps/sec
# INFO:tensorflow:step = 1000
# INFO:tensorflow:	 set goal dist = 2
# Executing op __inference_reset_19579082 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Identity in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_run_19579461 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op __inference_mean_19579508 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -15.30
# Executing op ConcatV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op MatMul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op BiasAdd in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Relu in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Tanh in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Cast in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Softmax in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Range in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op ExpandDims in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Tile in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Sum in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Pack in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op Mean in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op StridedSlice in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 predicted_dist = 13.0 (1.0)
# INFO:tensorflow:	 set goal dist = 5
# Executing op __inference_run_19581489 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -19.40
# INFO:tensorflow:		 predicted_dist = 14.5 (1.0)
# INFO:tensorflow:	 set goal dist = 10
# Executing op __inference_run_19583475 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 15.2 (0.8)
# INFO:tensorflow:	 eval_time = 1.27
#  67%|███████████████████████████████████████████████████▏                         | 1996/3000 [00:12<00:04, 213.47it/s]
# Saved checkpoint for step 2000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-13-2021-10-58-11-PM\ckpt\ckpt-2
# INFO:tensorflow:step = 2000, loss = 2.100226
# INFO:tensorflow:228.745 steps/sec
# INFO:tensorflow:step = 2000
# INFO:tensorflow:	 set goal dist = 2
# Executing op __inference_run_19617805 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -11.40
# INFO:tensorflow:		 predicted_dist = 13.7 (2.7)
# INFO:tensorflow:	 set goal dist = 5
# Executing op __inference_run_19619791 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -16.80
# INFO:tensorflow:		 predicted_dist = 16.6 (0.9)
# INFO:tensorflow:	 set goal dist = 10
# Executing op __inference_run_19621777 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -18.00
# INFO:tensorflow:		 predicted_dist = 17.4 (0.7)
# INFO:tensorflow:	 eval_time = 1.07
#  99%|████████████████████████████████████████████████████████████████████████████▌| 2982/3000 [00:18<00:00, 207.19it/s]
# Saved checkpoint for step 3000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-13-2021-10-58-11-PM\ckpt\ckpt-3
# INFO:tensorflow:step = 3000, loss = 2.060184
# INFO:tensorflow:227.509 steps/sec
# INFO:tensorflow:step = 3000
# INFO:tensorflow:	 set goal dist = 2
# Executing op __inference_run_19656107 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -3.60
# INFO:tensorflow:		 predicted_dist = 11.6 (2.4)
# INFO:tensorflow:	 set goal dist = 5
# Executing op __inference_run_19658093 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -12.20
# INFO:tensorflow:		 predicted_dist = 15.5 (1.5)
# INFO:tensorflow:	 set goal dist = 10
# Executing op __inference_run_19660079 in device /job:localhost/replica:0/task:0/device:CPU:0
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -19.70
# INFO:tensorflow:		 predicted_dist = 17.0 (1.0)
# INFO:tensorflow:	 eval_time = 0.98
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:19<00:00, 150.94it/s]
# Executing op FlushSummaryWriter in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DeleteIterator in device /job:localhost/replica:0/task:0/device:CPU:0
# Executing op DestroyResourceOp in device /job:localhost/replica:0/task:0/device:CPU:0
# LossInfo(loss=<tf.Tensor: id=19655850, shape=(), dtype=float32, numpy=2.0601835>, extra=(<tf.Tensor: id=19655851, shape=(), dtype=float32, numpy=0.18084712>, <tf.Tensor: id=19655852, shape=(), dtype=float32, numpy=1.8793364>))

# %% [markdown]
# # Load trained model into agent

# %%
filename = "FourRooms_coordinate_20steps-Dec-05-2019-12-58-28-PM/ckpt/"
checkpoint_file = os.path.join(model_dir, filename)

ckpt = tf.train.Checkpoint(step=tf.Variable(1), net=agent)
manager = tf.train.CheckpointManager(ckpt, checkpoint_file, max_to_keep=3)
ckpt.restore(manager.latest_checkpoint)

# %% [markdown]
# # Fill replay buffer with random prefectly explored data

# %%
from sgm.envs import *

#@title Fill the replay buffer with random data  {vertical-output: true, run: "auto" }
replay_buffer_size = 2000 #@param {min:100, max: 1000, step: 100, type:"slider"}

eval_tf_env.pyenv.envs[0].gym.set_sample_goal_args(
    prob_constraint=0.0,
    min_dist=0,
    max_dist=np.inf)
rb_vec = []
for it in range(replay_buffer_size):
    ts = eval_tf_env.reset()
    rb_vec.append(ts.observation['observation'].numpy()[0])
rb_vec = np.array(rb_vec)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(*rb_vec.T)
plot_walls(eval_tf_env.pyenv.envs[0].env.walls)
plt.show()

# %% [markdown]
# # Calculate qvalue distances

# %%
pdist = agent._get_pairwise_dist(rb_vec, aggregate=None).numpy()

# %%
plt.figure(figsize=(6, 3))
plt.hist(pdist.flatten(), bins=range(20))
plt.xlabel('predicted distance')
plt.ylabel('number of (s, g) pairs')
plt.show()

# %% [markdown]
# # Calculate Euclidean distances

# %%
from scipy.spatial import distance
euclidean_dists = distance.pdist(rb_vec)

plt.figure(figsize=(6, 3))
plt.hist(euclidean_dists.flatten())
plt.xlabel('Euclidean distance')
plt.ylabel('number of pairwise distances')
plt.show()

# %% [markdown]
# # Initialize SoRB search policy

# %%
from sgm.planner import SoRBSearchPolicy
search_policy_type = "SoRB"
agent.initialize_search(rb_vec, max_search_steps=6)
search_policy = SoRBSearchPolicy(agent, pdist, rb_vec)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# WARNING:tensorflow:From d:\study\cse 257\sgm\sgm\agent.py:158: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Plotting 1954 nodes and 19816 edges

# %% [markdown]
# # Cleanup and evaluate SoRB

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.6
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 5000
eval_period = 500

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SoRB has initial success rate 0.05
# Evaluated initial SoRB success rate in 353.16 seconds
# After filtering and 0 cleanup steps, SoRB has success rate 0.30
# Took 500 cleanup steps and evaluated SoRB success rate in 841.19 seconds
# After filtering and 500 cleanup steps, SoRB has success rate 0.20
# Took 500 cleanup steps and evaluated SoRB success rate in 930.83 seconds
# After filtering and 1000 cleanup steps, SoRB has success rate 0.30
# Took 500 cleanup steps and evaluated SoRB success rate in 1078.80 seconds
# After filtering and 1500 cleanup steps, SoRB has success rate 0.25
# Took 500 cleanup steps and evaluated SoRB success rate in 1097.61 seconds
# After filtering and 2000 cleanup steps, SoRB has success rate 0.10
# Took 500 cleanup steps and evaluated SoRB success rate in 1088.33 seconds
# After filtering and 2500 cleanup steps, SoRB has success rate 0.30
# Took 500 cleanup steps and evaluated SoRB success rate in 1043.78 seconds
# After filtering and 3000 cleanup steps, SoRB has success rate 0.20
# Took 500 cleanup steps and evaluated SoRB success rate in 1007.75 seconds
# After filtering and 3500 cleanup steps, SoRB has success rate 0.20
# Took 500 cleanup steps and evaluated SoRB success rate in 750.08 seconds
# After filtering and 4000 cleanup steps, SoRB has success rate 0.20
# Took 500 cleanup steps and evaluated SoRB success rate in 711.81 seconds
# After filtering and 4500 cleanup steps, SoRB has success rate 0.30
# Took 500 cleanup steps and evaluated SoRB success rate in 723.58 seconds
# After filtering and 5000 cleanup steps, SoRB has success rate 0.15

# %% [markdown]
# # Visualize SoRB cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1954 nodes and 19816 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1954 nodes and 9234 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1954 nodes and 9166 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1954 nodes and 68 edges

# %% [markdown]
# # Initialize SGM search policy

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=6) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=6)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# WARNING:tensorflow:From d:\study\cse 257\sgm\sgm\agent.py:158: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Plotting 225 nodes and 2212 edges

# %% [markdown]
# # Cleanup and evaluate SGM

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.6
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 5000
eval_period = 500

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SGM has initial success rate 0.25
# Evaluated initial SGM success rate in 264.75 seconds
# After filtering and 0 cleanup steps, SGM has success rate 0.15
# Took 500 cleanup steps and evaluated SGM success rate in 319.25 seconds
# After filtering and 500 cleanup steps, SGM has success rate 0.30
# Took 500 cleanup steps and evaluated SGM success rate in 300.69 seconds
# After filtering and 1000 cleanup steps, SGM has success rate 0.15
# Took 500 cleanup steps and evaluated SGM success rate in 325.58 seconds
# After filtering and 1500 cleanup steps, SGM has success rate 0.55
# Took 500 cleanup steps and evaluated SGM success rate in 232.28 seconds
# After filtering and 2000 cleanup steps, SGM has success rate 0.35
# Took 500 cleanup steps and evaluated SGM success rate in 267.81 seconds
# After filtering and 2500 cleanup steps, SGM has success rate 0.25
# Took 500 cleanup steps and evaluated SGM success rate in 296.14 seconds
# After filtering and 3000 cleanup steps, SGM has success rate 0.65
# Took 500 cleanup steps and evaluated SGM success rate in 191.94 seconds
# After filtering and 3500 cleanup steps, SGM has success rate 0.55
# Took 500 cleanup steps and evaluated SGM success rate in 228.98 seconds
# After filtering and 4000 cleanup steps, SGM has success rate 0.65
# Took 500 cleanup steps and evaluated SGM success rate in 193.42 seconds
# After filtering and 4500 cleanup steps, SGM has success rate 0.55
# Took 500 cleanup steps and evaluated SGM success rate in 228.00 seconds
# After filtering and 5000 cleanup steps, SGM has success rate 0.55

# %% [markdown]
# # Visualize SoRB cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 225 nodes and 2212 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 225 nodes and 1098 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 225 nodes and 1055 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 225 nodes and 43 edges

# %% [markdown]
# # Reference

# %% [markdown]
# S. Emmons, A. Jain, M. Laskin, T. Kurutach, P. Abbeel, and D. Pathak. Sparse Graphical Memory for Robust Planning. NeurIPS, 2020. https://github.com/scottemmons/sgm
