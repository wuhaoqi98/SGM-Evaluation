# %%
# Reload modules whenever underlying code changes
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
from sgm.dependencies import *

# %% [markdown]
# # Initialize untrained agent

# %%
tf.reset_default_graph()

# %%
from sgm.envs import env_load_fn
from sgm.agent import UvfAgent

# If you change the environment parameters below, make sure to run
# tf.reset_default_graph() in the cell above before training.
max_episode_steps = 20
env_name = 'Maze11x11'  # Choose one of the environments shown above. 
resize_factor = 1  # Inflate the environment to increase the difficulty.
thin = True # If True, resize by expanding open space, not walls, to make walls thin
desc_name = "thinned_" + env_name.lower() if thin else env_name.lower()

base_dir = os.path.join(os.getcwd(), os.pardir, "agents")
model_dir = os.path.join(base_dir, desc_name)

tf_env = env_load_fn(env_name, max_episode_steps,
                     resize_factor=resize_factor,
                     terminate_on_timeout=False,
                     thin=thin)

eval_tf_env = env_load_fn(env_name, max_episode_steps,
                          resize_factor=resize_factor,
                          terminate_on_timeout=True,
                          thin=thin)

agent = UvfAgent(
    tf_env.time_step_spec(),
    tf_env.action_spec(),
    max_episode_steps=max_episode_steps,
    use_distributional_rl=True,
    ensemble_size=3)
# Out:
# WARNING:tensorflow:From d:\anaconda3\envs\sgm\lib\site-packages\tf_agents\agents\ddpg\actor_network.py:101: The name tf.keras.initializers.RandomUniform is deprecated. Please use tf.compat.v1.keras.initializers.RandomUniform instead.
# d:\anaconda3\envs\sgm\lib\site-packages\gym\logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))

# %% [markdown]
# # Train the agent

# %%
from sgm.trainer import train_eval

train_eval(agent,
           tf_env,
           eval_tf_env,
           initial_collect_steps=1000,
           eval_interval=1000,
           num_eval_episodes=10,
           num_iterations=3000,
           save_model_dir=model_dir,
           experiment_name=f"{env_name}_coordinate_{max_episode_steps}steps")
# Out:
# INFO:tensorflow:random_seed = 0
# WARNING:tensorflow:From d:\anaconda3\envs\sgm\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1781: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From d:\anaconda3\envs\sgm\lib\site-packages\tf_agents\replay_buffers\tf_uniform_replay_buffer.py:545: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# INFO:tensorflow:Saving checkpoints to directory D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-23-2021-10-29-27-PM\ckpt
# INFO:tensorflow:Creating tensorboard summary writer with directory D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-23-2021-10-29-27-PM
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#  33%|█████████████████████████▍                                                    | 978/3000 [00:05<00:08, 234.72it/s]
# Saved checkpoint for step 1000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-23-2021-10-29-27-PM\ckpt\ckpt-1
# INFO:tensorflow:step = 1000, loss = 2.361648
# INFO:tensorflow:181.995 steps/sec
# INFO:tensorflow:step = 1000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -13.30
# INFO:tensorflow:		 predicted_dist = 12.9 (2.0)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -18.50
# INFO:tensorflow:		 predicted_dist = 15.1 (0.9)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 15.8 (1.2)
# INFO:tensorflow:	 eval_time = 1.38
#  66%|██████████████████████████████████████████████████▊                          | 1979/3000 [00:11<00:04, 227.07it/s]
# Saved checkpoint for step 2000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-23-2021-10-29-27-PM\ckpt\ckpt-2
# INFO:tensorflow:step = 2000, loss = 2.228857
# INFO:tensorflow:251.382 steps/sec
# INFO:tensorflow:step = 2000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -7.00
# INFO:tensorflow:		 predicted_dist = 9.4 (3.0)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -13.00
# INFO:tensorflow:		 predicted_dist = 14.8 (2.0)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 17.1 (1.1)
# INFO:tensorflow:	 eval_time = 0.85
# 100%|████████████████████████████████████████████████████████████████████████████▉| 2999/3000 [00:17<00:00, 196.70it/s]
# Saved checkpoint for step 3000: D:\Study\CSE 257\SGM\notebooks\..\agents\thinned_maze11x11\Maze11x11_coordinate_20steps-May-23-2021-10-29-27-PM\ckpt\ckpt-3
# INFO:tensorflow:step = 3000, loss = 2.743765
# INFO:tensorflow:242.748 steps/sec
# INFO:tensorflow:step = 3000
# INFO:tensorflow:	 set goal dist = 2
# INFO:tensorflow:		 AverageReturn (eval distance=2.000000) -4.90
# INFO:tensorflow:		 predicted_dist = 7.6 (2.9)
# INFO:tensorflow:	 set goal dist = 5
# INFO:tensorflow:		 AverageReturn (eval distance=5.000000) -13.40
# INFO:tensorflow:		 predicted_dist = 14.0 (1.9)
# INFO:tensorflow:	 set goal dist = 10
# INFO:tensorflow:		 AverageReturn (eval distance=10.000000) -20.00
# INFO:tensorflow:		 predicted_dist = 14.8 (1.9)
# INFO:tensorflow:	 eval_time = 0.85
# 100%|█████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:18<00:00, 166.42it/s]
# LossInfo(loss=<tf.Tensor: id=115152, shape=(), dtype=float32, numpy=2.7437654>, extra=(<tf.Tensor: id=115153, shape=(), dtype=float32, numpy=0.36533517>, <tf.Tensor: id=115154, shape=(), dtype=float32, numpy=2.3784301>))

# %% [markdown]
# # Load trained model into agent

# %%
filename = "Maze11x11/ckpt/"
checkpoint_file = os.path.join(model_dir, filename)

ckpt = tf.train.Checkpoint(step=tf.Variable(1), net=agent)
manager = tf.train.CheckpointManager(ckpt, checkpoint_file, max_to_keep=3)
ckpt.restore(manager.latest_checkpoint)

# %% [markdown]
# # Fill replay buffer with random prefectly explored data

# %%
from sgm.envs import *

#@title Fill the replay buffer with random data  {vertical-output: true, run: "auto" }
replay_buffer_size = 2000 #@param {min:100, max: 1000, step: 100, type:"slider"}

eval_tf_env.pyenv.envs[0].gym.set_sample_goal_args(
    prob_constraint=0.0,
    min_dist=0,
    max_dist=np.inf)
rb_vec = []
for it in range(replay_buffer_size):
    ts = eval_tf_env.reset()
    rb_vec.append(ts.observation['observation'].numpy()[0])
rb_vec = np.array(rb_vec)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(*rb_vec.T)
plot_walls(eval_tf_env.pyenv.envs[0].env.walls)
plt.show()

# %% [markdown]
# # Calculate qvalue distances

# %%
pdist = agent._get_pairwise_dist(rb_vec, aggregate=None).numpy()

# %%
plt.figure(figsize=(6, 3))
plt.hist(pdist.flatten(), bins=range(20))
plt.xlabel('predicted distance')
plt.ylabel('number of (s, g) pairs')
plt.show()

# %% [markdown]
# # Calculate Euclidean distances

# %%
from scipy.spatial import distance
euclidean_dists = distance.pdist(rb_vec)

plt.figure(figsize=(6, 3))
plt.hist(euclidean_dists.flatten())
plt.xlabel('Euclidean distance')
plt.ylabel('number of pairwise distances')
plt.show()

# %% [markdown]
# # Initialize SoRB search policy

# %%
from sgm.planner import SoRBSearchPolicy
search_policy_type = "SoRB"
agent.initialize_search(rb_vec, max_search_steps=5)
search_policy = SoRBSearchPolicy(agent, pdist, rb_vec)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1911 nodes and 98463 edges

# %% [markdown]
# # Cleanup and evaluate SoRB

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.2
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 5000
eval_period = 500

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SoRB has initial success rate 0.40
# Evaluated initial SoRB success rate in 321.08 seconds
# After filtering and 0 cleanup steps, SoRB has success rate 0.15
# Took 500 cleanup steps and evaluated SoRB success rate in 2149.22 seconds
# After filtering and 500 cleanup steps, SoRB has success rate 0.25
# Took 500 cleanup steps and evaluated SoRB success rate in 3826.31 seconds
# After filtering and 1000 cleanup steps, SoRB has success rate 0.05
# Took 500 cleanup steps and evaluated SoRB success rate in 5331.77 seconds
# After filtering and 1500 cleanup steps, SoRB has success rate 0.10
# Took 500 cleanup steps and evaluated SoRB success rate in 4768.78 seconds
# After filtering and 2000 cleanup steps, SoRB has success rate 0.00
# Took 500 cleanup steps and evaluated SoRB success rate in 3303.00 seconds
# After filtering and 2500 cleanup steps, SoRB has success rate 0.10
# Took 500 cleanup steps and evaluated SoRB success rate in 3115.11 seconds
# After filtering and 3000 cleanup steps, SoRB has success rate 0.05
# Took 500 cleanup steps and evaluated SoRB success rate in 4432.38 seconds
# After filtering and 3500 cleanup steps, SoRB has success rate 0.00
# Took 500 cleanup steps and evaluated SoRB success rate in 3491.12 seconds
# After filtering and 4000 cleanup steps, SoRB has success rate 0.00
# Took 500 cleanup steps and evaluated SoRB success rate in 2254.44 seconds
# After filtering and 4500 cleanup steps, SoRB has success rate 0.10
# Took 500 cleanup steps and evaluated SoRB success rate in 4860.39 seconds
# After filtering and 5000 cleanup steps, SoRB has success rate 0.15

# %% [markdown]
# # Visualize SoRB cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1911 nodes and 98463 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1911 nodes and 9453 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1911 nodes and 9265 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 1911 nodes and 188 edges

# %% [markdown]
# # Initialize SGM search policy

# %%
from sgm.planner import SGMSearchPolicy
search_policy_type = "SGM"
agent.initialize_search(rb_vec, max_search_steps=5) # needed to set agent attributes that SGMSearchPolicy constructor queries
search_policy = SGMSearchPolicy(agent, pdist, rb_vec, rb_vec, cache_pdist = True)
agent.initialize_search(search_policy.rb_vec, max_search_steps=5)

from sgm.utils.visualization import *
plot_graph(search_policy._g.copy(), search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 169 nodes and 3708 edges

# %% [markdown]
# # Cleanup and evaluate SGM

# %%
from sgm.evaluation import cleanup_and_eval

logdir = os.path.join(os.getcwd(), os.pardir, "logs")
eval_difficulty = 0.2
k_nearest = 5
eval_trials = 20
total_cleanup_steps = 5000
eval_period = 500

logfolder = cleanup_and_eval(search_policy,
                             search_policy_type,
                             desc_name,
                             eval_tf_env,
                             logdir,
                             eval_difficulty=eval_difficulty,
                             k_nearest=k_nearest,
                             eval_trials=eval_trials,
                             total_cleanup_steps=total_cleanup_steps,
                             eval_period=eval_period)
# Out:
# SGM has initial success rate 0.55
# Evaluated initial SGM success rate in 186.45 seconds
# After filtering and 0 cleanup steps, SGM has success rate 0.05
# Took 500 cleanup steps and evaluated SGM success rate in 343.77 seconds
# After filtering and 500 cleanup steps, SGM has success rate 0.20
# Took 500 cleanup steps and evaluated SGM success rate in 313.39 seconds
# After filtering and 1000 cleanup steps, SGM has success rate 0.40
# Took 500 cleanup steps and evaluated SGM success rate in 264.61 seconds
# After filtering and 1500 cleanup steps, SGM has success rate 0.30
# Took 500 cleanup steps and evaluated SGM success rate in 293.73 seconds
# After filtering and 2000 cleanup steps, SGM has success rate 0.25
# Took 500 cleanup steps and evaluated SGM success rate in 321.52 seconds
# After filtering and 2500 cleanup steps, SGM has success rate 0.35
# Took 500 cleanup steps and evaluated SGM success rate in 317.16 seconds
# After filtering and 3000 cleanup steps, SGM has success rate 0.25
# Took 500 cleanup steps and evaluated SGM success rate in 342.12 seconds
# After filtering and 3500 cleanup steps, SGM has success rate 0.45
# Took 500 cleanup steps and evaluated SGM success rate in 293.89 seconds
# After filtering and 4000 cleanup steps, SGM has success rate 0.25
# Took 500 cleanup steps and evaluated SGM success rate in 332.42 seconds
# After filtering and 4500 cleanup steps, SGM has success rate 0.10
# Took 500 cleanup steps and evaluated SGM success rate in 331.19 seconds
# After filtering and 5000 cleanup steps, SGM has success rate 0.20

# %% [markdown]
# # Visualize SoRB cleanup graphs

# %%
from sgm.utils.visualization import *

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_initial"))
initial_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_0_cleanup_steps/"))
filtered_graph = search_policy._g.copy()

search_policy.load(os.path.join(logfolder, search_policy_type.lower().replace(" ", "_") + "_filtered_{}_cleanup_steps/".format(total_cleanup_steps)))
cleaned_graph = search_policy._g.copy()

pruned_graph = nx.difference(filtered_graph, cleaned_graph)

# %%
plot_points(search_policy.rb_vec, eval_tf_env)

# %%
plot_graph(initial_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 169 nodes and 3708 edges

# %%
plot_graph(filtered_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 169 nodes and 845 edges

# %%
plot_graph(cleaned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 169 nodes and 787 edges

# %%
plot_graph(pruned_graph, search_policy.rb_vec, eval_tf_env)
# Out:
# Plotting 169 nodes and 58 edges
